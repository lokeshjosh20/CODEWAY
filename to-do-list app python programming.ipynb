# %%
class Task:
    def __init__(self, title, description, due_date):
        self.title = title
        self.description = description
        self.due_date = due_date
        self.status = "Incomplete"

    def mark_as_complete(self):
        self.status = "Complete"


class TodoList:
    def __init__(self):
        self.tasks = []

    def add_task(self, task):
        self.tasks.append(task)

    def remove_task(self, task):
        self.tasks.remove(task)

    def list_tasks(self):
        for index, task in enumerate(self.tasks, start=1):
            print(f"{index}. {task.title} - {task.status}")

    def update_task(self, index, **kwargs):
        for key, value in kwargs.items():
            setattr(self.tasks[index], key, value)


def main():
    todo_list = TodoList()

    while True:
        print("\n1. Add Task")
        print("2. Remove Task")
        print("3. List Tasks")
        print("4. Mark Task as Complete")
        print("5. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            title = input("Enter task title: ")
            description = input("Enter task description: ")
            due_date = input("Enter due date: ")
            task = Task(title, description, due_date)
            todo_list.add_task(task)
        elif choice == "2":
            todo_list.list_tasks()
            index = int(input("Enter index of task to remove: ")) - 1
            del todo_list.tasks[index]
        elif choice == "3":
            todo_list.list_tasks()
        elif choice == "4":
            todo_list.list_tasks()
            index = int(input("Enter index of task to mark as complete: ")) - 1
            todo_list.tasks[index].mark_as_complete()
        elif choice == "5":
            break
        else:
            print("Invalid choice. Please try again.")


if __name__ == "__main__":
    main()
# Out:
# 1. Add Task
# 2. Remove Task
# 3. List Tasks
# 4. Mark Task as Complete
# 5. Exit
# Enter your choice: 1
# Enter task title: project
# Enter task description: to do list
# Enter due date: 5/2/2024
#
# 1. Add Task
# 2. Remove Task
# 3. List Tasks
# 4. Mark Task as Complete
# 5. Exit
# Enter your choice: 3
# 1. project - Incomplete
#
# 1. Add Task
# 2. Remove Task
# 3. List Tasks
# 4. Mark Task as Complete
# 5. Exit
# Enter your choice: 4
# 1. project - Incomplete
# Enter index of task to mark as complete: 1
#
# 1. Add Task
# 2. Remove Task
# 3. List Tasks
# 4. Mark Task as Complete
# 5. Exit
# Enter your choice: 4
# 1. project - Complete
# Enter index of task to mark as complete: 1
#
# 1. Add Task
# 2. Remove Task
# 3. List Tasks
# 4. Mark Task as Complete
# 5. Exit
# Enter your choice: 5
